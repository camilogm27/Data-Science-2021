# %% [markdown]
# # <center>Análisis poblacional del panorama político y perspectivas para las elecciones presidenciales de 2022 en Colombia .</center>
# $\color{black}{Juan\;Camilo\;García\;Malagón}$
# ## <center> $\color{blue}{\text{Business understanding}}$ </center>

# %% [markdown]
# $\color{blue}{\text{Introducción}}$

# %% [markdown]
# Hoy en día y desde siempre la política ha representado uno de los ambitos más marcados en la socidad, la postura política de un individuo usualmente recae en quien considera representa sus ideales (aunque esto no siempre ocurra);La política se encuentra intrínsecamente relacionada con poder y este resulta ser codiciado por un grupo puntual de individuos de la sociedad,especificamente los partidos politicos y a su vez de todos sus filiales y contribuyentes pues aunque la figura de Presidente represente un sustantivo singular de este dependen muchos de los altos cargos y toma de decisiones futuras para todos los habitantes.
#
# Aunque la política en Colombia se ha distinguido por el bipartidismo desde la constitución del 1991 se da via libre al multipartidismo con lo cual los partidos políticos cobran una figura de gran influencia y a su vez los encargados de representarlos y competir con sus homólogos.En la actualidad compañias destacadas como GUARUMO,INVAMER,MOE y el CNC,Centro Nacional de Consultoría son los encargados de realizar encuestas ,sondeos y datos respecto al panorama político en Colombia proporcionando una visión general a la población respecto a las preferencias y favoritismos políticos de la mayoria ,pero además proporcionando la llave maestra a los partidos y sus canditatos respecto a cual grupo social de sufragantes podria ser crucial ganar en la siguiente contienda electoral.
#
# El presente proyecto de Ciencia de datos empleando el proceso estándar entre industrias para la minería de datos (CRISP-DM) pretende estudiar las estadisticas políticas registradas en los ultimos periodos electorales dando un panorama de necesidades y preferencias de los ciudadanos el cual resulta de gran interés y utilidad para partidos politicos,agencias de publicidad,gremios sociales-económicos y otras diferentes esferas sociales.

# %% [markdown]
# $\color{blue}{\text{Importancia del problema}}$

# %% [markdown]
# $\color{blue}{\text{Estado del arte}}$

# %% [markdown]
# $Sistema\;Electoral\;Colombiano$

# %% [markdown]
# Sistema de eleccion popular donde los integrantes de los partidos politicos son escogidos para los diferentes cargos gubernamentales.
#
# Se encuentra a cargo del CNE (Consejo Nacional Electoral)- y Registraduria Nacional del Estado Civil
# Velar por las normas electorales del Codigo electoral colombiano
#
# **CNE (Consejo Nacional Electoral)**
#
# -Organismo autonomo e independiente parte de la organización electoral  establecido mediante el articulo 120 de la constitucion Politica Colombiana
# -Se ecuentra conformado por 9 magistrados elegidos en Congreso
#
# **Registraduria Nacional del Estado Civil**
#
# Igualmente que el CNE es una institutcion de descentralizada de carácter publico encargada de la organización electoral
# Según establece el artículo 266 de la Constitución Política de Colombia, el Registrador Nacional del Estado Civil será escogido por los Presidentes de la Corte Constitucional, la Corte Suprema de Justicia y el Consejo de Estado, mediante concurso de méritos organizado según la ley
#
# **Codigo electoral colombiano**
#
# Actualmente rige el codigo electoral establecido en el decredto 2241 de 1986 en el cual se estipulan autoridades electorales, delegados, partes,funciones,disposiciones y capacidades de las distintas partes de los miembros electorales
# Actualmente se encuentra en tramite como ley estatutaria un codigo electoral en Congreso (Camara y Senado deciden)

# %% [markdown]
# $\color{blue}{\text{Business Objectives and Success Criteria}}$

# %% [markdown]
# **Objetivo general:**

# %% [markdown]
# Analizar los comportamientos electorales de la elección de la figura Presidencial en Colombia en los ultimos años mediante los datos registrados de sufragios en las anteriores contiendas analizando variables como la dominancia politica,la representatividad y no representatividad,voter turnout,ergonomía electoral entre otras variables contrastando con las proyecciones actuales de los candidatos presidenciales para el periodo electoral 2022-2026

# %% [markdown]
# **Objetivos especificos:**

# %% [markdown]
# - Dar un panorama político por departamentos con base en sus comportamientos electorales previos
# - Adquirir bases de datos referentes a las elecciones de los periodos 2014-2018 y 2018-2022 de los datos públicos  recopilados por gobierno y registraduría
# - Investigar los diferentes patrones de distribuciones de probabilidad asociados a las encuestas y resultados hechos durante las anteriores campañas electorales

# %% [markdown]
# **Criterios de éxito del Proyecto**

# %% [markdown]
# - Tener un rango de proximidad con base en el análisis hecho frente a las encuestas actuales para los distintos departamentos y regiones
# - Concluir en tiempo oportuno el análisis electoral propuesto
# - Obtener posibles escenarios de los cuales se puedan derivar estrategias de utilidad para los distintos actores interesados en la próxima contienda electoral
# - Lograr ajustes en los patrones de distribuciones de probabilidad de buena calidad con los datos recopilados

# %% [markdown]
# $Resource\;Inventory$

# %% [markdown]
# - Computadora con lenguaje de programación Python 3.8.5 y librerias necesarias.
# - Datos proporcionados por entidades gubernamentales sobre resultados y sondeos de elecciones, preferencias partidarias y candidaduras anteriores.
# - Equipo de expertos y analistas en contiendas políticas y asesores de campañas.

# %% [markdown]
# $Requirements, Assumptions, and\;Constraints$

# %% [markdown]
# **Requirements**
# - Los datos son de caracter público para una mayor reproducibilidad.
# - En principio no existe obligación o requerimiento contractual de publicar o compartir los datos obtenidos de este proyecto sin embargo existe la posibilidad de implementarlo en un tablero de control.

# %% [markdown]
# **Assumptions**
# - El proyecto responde a una actividad netamente académica sin ánimo de lucro por lo cual no correlaciona ningún factor económico
# - Los datos pueden presentar un sesgo estadistico debido a los margenes de error y posibles errores humanos en los conteos.
# - Para los posibles clientes o patrocinadores son mas fructiferos los resultados derivados de este estudio como posibles estrategias de campaña más que el proyecto en si mismo

# %% [markdown]
# **Constraints**
# - Los únicos requerimientos legales del tratamiento de las bases de datos usadas es no comprotemer de forma directa o directa alguna entidad gubernamental o en nombre de esta lo cual claramente no se pretende al ser un ejercicio académico

# %% [markdown]
# $Risks\;and\;Contingencies$

# %% [markdown]
# - Programación: Ante un posible retraso del proyecto se considera la reprogramación del calendario previsto para la mayor realización porcentual del proyecto
#
# - Financiero: No aplica
#
# - Datos: Existe un margen de error respecto a la calidad de los datos proporcionados pues algunos de estos por su magnitud aún estan sujetos a verifación
#
# - Resultados: Existe la posibilidad de escenarios mas leves o con menos información que los planteados inicialmente los cuales no dejan de contener información valiosa para los potenciales clientes a primera estancia.

# %% [markdown]
# $Cost\;/Benefit\;Analysis$

# %% [markdown]
# **Costos**

# %% [markdown]
# De forma ideal se plantea la necesidad de:
# - Un consultor conocedor del panorama politico
# - Un cientifico de datos para el tratamiento y manejo de la BigData
# - Un equipo de encuestadores para el muestro y verifación de posibles escenarios en determinados grupos poblacionales

# %% [markdown]
# **Beneficios**

# %% [markdown]
# - Poder generar un planteamiento óptimo de recursos de campaña
# - A partir de los resultados plantear ideas ,estrategias y propuestas optimas para ganar sufragantes en las poblaciones espeficas.

# %% [markdown]
# $Determining\;Data\;Mining\;Goals$

# %% [markdown]
# - Recopilar los datos históricos de periodos anteriores para realizar el data screening de los mismos (Market basket analysis):
# - Establecer ajustes a funciones de densidad de probabilidad para las diferentes variables asociadas a las bases de datos de encuestas y resultados de campañas electorales anteriores (Profiling)
# - Proyectar escenarios electorales bien ya sea un posible victoria de un candidato en primera vuelta o una posible contienda en segunda vuelta de dos de ellos (Sequence analysis)

# %% [markdown]
# **Criterios de éxito del Proyecto**

# %% [markdown]
# - Obtener posibles escenarios de los cuales se puedan derivar estrategias de utilidad para los distintos actores interesados en la próxima contienda electoral
# - Lograr ajustes en los patrones de distribuciones de probabilidad con una buena bondad de ajuste medida a través de diferentes test
# - Establecer una métrica que permita cuantificar la certeza de los resultados con unos umbrales de desviación.

# %% [markdown]
# $Project\;Plan$

# %% [markdown]
# | Fase | Tiempo | Recursos | Riesgos |
# |:-:|:-:|:-:|:-:|
# | Entendimiento del negocio | 1 semana | Todos los análisis | Cambio de presupuesto para  la ejecución del proyecto |
# | Entendimiento de los datos | 2 semana | Equipos de muestreo y sondeo de  intenciones de voto y consultor  político | Problema en la recopilación de datos, problemas técnicos y sesgos estadísticos |
# | Preparación de los datos | 2 semanas | Científico y analista de datos | Problema en los datos,  problemas técnicos |
# | Evaluación | 2 semana | Consultor político y científico de   datos | Cambios de presupuesto,  inhabilidad de publicación  de proyecciones del modelo |

# %% [markdown]
# ## <center> $\color{blue}{\text{Data understanding}}$ </center>

# %% [markdown]
# **Data Quantity**
#
# * *Formato*: Data estructurada en archivo xlsx
# * *Fuente* : Registraduría Nacional del Estado Civil
# * *Obtención* : Escrutinio de mesas de votantes
#     * Primera Vuelta: https://www.registraduria.gov.co/IMG/xlsx/PRE_1ERA_VUELTA_MMV_2014.xlsx
#         * 704176 Filas x 16 Columnas
#
#     * Segunda Vuelta: https://www.registraduria.gov.co/IMG/xlsx/PRE_2DA_VUELTA_MMV_2014.xlsx
#
#         * 456253 Filas x 14 Columnas

# %%
import pandas as pd
import numpy as np

# %%
URL='DATOS_01_14.xlsx'
Datos_01_2014=pd.read_excel(URL)

# %%
Datos_01_2014.columns
# Out:
# Index(['DIVIPOL_MESA', 'DIVIPOL', 'COD_DEP', 'DEPARTAMENTO', 'COD_MUN',
#        'MUNICIPIO', 'ZONA', 'PUESTO', 'MESA', 'JAL', 'BOLETIN', 'COD_PARTIDO',
#        'NOMB_PARTIDO', 'COD_CANDIDATO', 'NOMB_CANDIDATO', 'VOTOS'],
#       dtype='object')

# %%
Datos_01_2014
# Out:
#        DIVIPOL_MESA  DIVIPOL  COD_DEP DEPARTAMENTO  COD_MUN  MUNICIPIO  ZONA  \
# 0        10010101-1     1001        1    ANTIOQUIA        1   MEDELLIN     1
# 1        10010101-1     1001        1    ANTIOQUIA        1   MEDELLIN     1
# 2        10010101-1     1001        1    ANTIOQUIA        1   MEDELLIN     1
# 3        10010101-1     1001        1    ANTIOQUIA        1   MEDELLIN     1
# 4        10010101-1     1001        1    ANTIOQUIA        1   MEDELLIN     1
# ...             ...      ...      ...          ...      ...        ...   ...
# 704171  888157586-1    88815       88   CONSULADOS      815  VENEZUELA    75
# 704172  888157586-1    88815       88   CONSULADOS      815  VENEZUELA    75
# 704173  888157586-1    88815       88   CONSULADOS      815  VENEZUELA    75
# 704174  888157586-1    88815       88   CONSULADOS      815  VENEZUELA    75
# 704175  888157586-1    88815       88   CONSULADOS      815  VENEZUELA    75
#
# ...

# %%
URL='DATOS_02_14.xlsx'
Datos_02_2014=pd.read_excel(URL)

# %%
Datos_02_2014.columns
# Out:
# Index(['COD_DEP', 'DEPARTAMENTO', 'COD_MUN', 'MUNICIPIO', 'ZONA', 'PUESTO',
#        'MESA', 'JAL', 'BOLETIN', 'COD_PARTIDO', 'NOMBRE_PARTIDO',
#        'COD_CANDIDATO', 'NOMBRE_CANDIDATO', 'VOTOS'],
#       dtype='object')

# %%
Datos_02_2014
# Out:
#         COD_DEP DEPARTAMENTO  COD_MUN  MUNICIPIO  ZONA PUESTO  MESA  JAL  \
# 0             1    ANTIOQUIA        1   MEDELLIN     1      1     1    0
# 1             1    ANTIOQUIA        1   MEDELLIN     1      1     1    0
# 2             1    ANTIOQUIA        1   MEDELLIN     1      1     1    0
# 3             1    ANTIOQUIA        1   MEDELLIN     1      1     1    0
# 4             1    ANTIOQUIA        1   MEDELLIN     1      1     1    0
# ...         ...          ...      ...        ...   ...    ...   ...  ...
# 446252       88   CONSULADOS      815  VENEZUELA    75     86     1    0
# 446253       88   CONSULADOS      815  VENEZUELA    75     86     1    0
# 446254       88   CONSULADOS      815  VENEZUELA    75     86     1    0
# 446255       88   CONSULADOS      815  VENEZUELA    75     86     1    0
# 446256       88   CONSULADOS      815  VENEZUELA    75     86     1    0
#
#         BOLETIN  COD_PARTIDO                                NOMBRE_PARTIDO  \
# ...

# %% [markdown]
# **Data Quality**

# %% [markdown]
# Los datos proporcionan la cantidad de votos registrados por ubicación geográfica y por partido político siendo de gran utilidad para el presente análisis pues se concentran el número de sufragantes afines a un partido político por región
#
# * Tipo :Se presentan datos en su mayoría númericos y cadenas de caracteres

# %% [markdown]
# **Notas**

# %% [markdown]
# * Es importante tener en cuenta el número de filas del archivo puesto que la lectura de estas requiere un tiempo considerable de procesamiento en Jupyter
# * Se toman en cuenta las bases de codigo abierto publicadas del año 2014 pues hasta la fecha no se tiene una data estructurada de los formatos E-24 Y E-26 del año 2018,periodo anterior.

# %%
import pandas as pd
import openpyxl
wb = openpyxl.load_workbook('METADATOS.xlsx')
ws = wb['meta_data']
md = pd.DataFrame(ws.values)
md.columns = md.iloc[0]
md = md.drop(0)
md.head(24)
# Out:
# 0         Metadato                                        Descripción  \
# 1     DIVIPOL_MESA  Corresponde al codigo DIVIPOL adjuntando el nú...
# 2          DIVIPOL   Es la división político administrativa en la ...
# 3          COD_DEP  Corresponde a un número asignado por el DANE a...
# 4     DEPARTAMENTO                            Nombre del departamento
# 5          COD_MUN  Corresponde al un número asignado por el DANE ...
# 6        MUNICIPIO                               Nombre del municipio
# 7             ZONA  Corresponde al número de división establecida ...
# 8           PUESTO  Corresponde la número de puesto de votación de...
# 9             MESA  Corresponde al número de mesa dispuesto en cad...
# 10     COD_PARTIDO  Corresponde al número asignado a los distintos...
# 11    NOMB_PARTIDO  Nombre del partido politico al cual pertenece ...
# 12   COD_CANDIDATO  Código asignado al candidado de cada partido e...
# ...

# %% [markdown]
# <img src="diagramaflujo.png">

# %% [markdown]
# **Limpieza y filtración de Datos**

# %% [markdown]
# * Primeramente de los datos originales se obseva la no variación en ninguna celda de las columnas 'JAL' e 'Informe' pues los datos se encuentran clasificados por código-zona por lo cual el dato de la Junta Local Administrativa a la cual se encuentra adscrita la zona no es relevante y además estos datos corresponden al conteo voto a voto final por la registraduría por lo cual corresponden todos solo a un mismo informe,el último y definitivo.
#
# * Es importante destacar que los datos 'voto en blanco','voto nulo' y 'voto no marcado' claramente no corresponden a ninguna partido político por lo cual las respectivas celdas se encuentran vacias

# %% [markdown]
# ## $\color{red}{--------------------------------------}$
# ## $\color{red}{Observaciones}$

# %% [markdown]
# - Se realizó una nueva busqueda de datos pues los suministrados por la registraduría y datos abiertos del gobierno presentan un sesgo temporal considerable y no presentan información representativa de una forma sólida .
# - Como lo planteado el Business Understanding se plantea la toma y procesamiento de datos de entidades externas como el caso de la Misión de Observación electoral la cual posee mayor variedad de datos y de mayor calidad por lo cual para obtener un mayor nivel de éxito en el presente proyecto de análisis de datos se considera necesario actualizar los módulos en lo que a data representan como los son Data Understading,MetaData,DataCleaning y DataScreening

# %% [markdown]
# ## $\color{red}{--------------------------------------}$

# %% [markdown]
# ## <center> $\color{blue}{\text{Data understanding}}$ </center>

# %%
import pandas as pd
import openpyxl
wb = openpyxl.load_workbook('DataSet.xlsx')
ws = wb['Hoja1']
md = pd.DataFrame(ws.values)
md.columns = md.iloc[0]
md = md.drop(0)
md.head(24)
# Out:
# 0    CARACTERISTICA   NaN                                            DATASET  \
# 1           ARCHIVO  None                        2014PresidentePrimeraVuelta
# 2         CONTENIDO  None  Votación Presidencial 2014 Primera vuelta por ...
# 3       DESCRIPCIÓN  None  Tabla de datos registrados en las elecciones p...
# 4      CONSTRUCCIÓN  None                Misión de Observación Electoral MOE
# 5   FUENTE DE DATOS  None            Registraduría Nacional del Estado Civil
# 6          KEYWORDS  None       Departamentos,Paticipación, Votos,Candidatos
# 7      LOCALIZACIÓN  None  https://www.datoselectorales.org/wp-content/up...
# 8             FECHA  None                                  Noviembre de 2014
# 9           FORMATO  None                                               XLSX
# 10         DERECHOS  None                                     Datos Abiertos
# 11             None  None                                               None
#
# ...

# %%
URL='2014PresidentePrimeraVuelta.xlsx'
HOJA='Presidencia 1raV 2014'
Datos_10_2014=pd.read_excel(URL,sheet_name=HOJA)

# %%
Datos_10_2014
# Out:
#         Code DANE       Municipio        Depto  Censo electoral  \
# 0            5001        Medellín    Antioquia          1412495
# 1            5002       Abejorral    Antioquia            14939
# 2            5004        Abriaquí    Antioquia             1903
# 3            5021      Alejandría    Antioquia             4377
# 4            5030           Amagá    Antioquia            20893
# ...           ...             ...          ...              ...
# 1118        99001  Puerto Carreño      Vichada            15621
# 1119        99524    La Primavera      Vichada             7190
# 1120        99624   Santa Rosalía      Vichada             2893
# 1121        99773        Cumaribo      Vichada            18562
# 1122  Consulados       Consulados  Consulados            851066
#
#       Participación  %Participación  Abstención   %Abstención  Votos válidos  \
# 0            700180        0.495704       712315     0.504296         682458
# ...

# %%
URL='2014PresidenteSegundaVuelta.xlsx'
HOJA='Presidencia 2daV 2014'
Datos_20_2014=pd.read_excel(URL,sheet_name=HOJA)

# %%
Datos_20_2014
# Out:
#       Code DANE       Municipio Departamento  Censo electoral  \
# 0          5001        Medellín    Antioquia          1412495
# 1          5002       Abejorral    Antioquia            14939
# 2          5004        Abriaquí    Antioquia             1903
# 3          5021      Alejandría    Antioquia             4377
# 4          5030           Amagá    Antioquia            20893
# ...         ...             ...          ...              ...
# 1117      97889       Yavaraté        Vaupés              994
# 1118      99001  Puerto Carreño      Vichada            15621
# 1119      99524    La Primavera      Vichada             7190
# 1120      99624   Santa Rosalía      Vichada             2893
# 1121      99773        Cumaribo      Vichada            18562
#
#       Participación / Total Votación  Abstención  \
# 0                             738993      673502
# 1                               6933        8006
# 2                                875        1028
# ...

# %%
URL='2018PresidentePrimeraVuelta.xlsx'
HOJA='Presidencia 1raV 2018'
Datos_10_2018=pd.read_excel(URL,sheet_name=HOJA)

# %%
Datos_10_2018
# Out:
#         Code       Municipio       Depto  Censo electoral   \
# 0       5001        Medellín   Antioquia           1588150
# 1       5002       Abejorral   Antioquia             14967
# 2       5004        Abriaquí   Antioquia              1913
# 3       5021      Alejandría   Antioquia              4549
# 4       5030           Amagá   Antioquia             22350
# ...      ...             ...         ...               ...
# 1118   99001  Puerto Carreño     Vichada             18553
# 1119   99524    La Primavera     Vichada              7116
# 1120   99624   Santa Rosalía     Vichada              3197
# 1121   99773        Cumaribo     Vichada             19585
# 1122  999999      Consulados  Cansulados            812071
#
#       Participación/Total votación   Abstención        Ganador  Votos Válidos  \
# 0                           1009878      578272     Iván Duque         998455
# 1                              6582        8385     Iván Duque           6408
# ...

# %%
URL='2018PresidenteSegundaVuelta.xlsx'
HOJA='Presidente 2daV 2018'
Datos_20_2018=pd.read_excel(URL,sheet_name=HOJA)

# %%
Datos_20_2018
# Out:
#         Code       Municipio        Depto  Censo electoral   \
# 0       5001        Medellín    Antioquia           1588150
# 1       5002       Abejorral    Antioquia             14967
# 2       5004        Abriaquí    Antioquia              1913
# 3       5021      Alejandría    Antioquia              4549
# 4       5030           Amagá    Antioquia             22350
# ...      ...             ...          ...               ...
# 1118   99001  Puerto Carreño      Vichada             18553
# 1119   99524    La Primavera      Vichada              7116
# 1120   99624   Santa Rosalía      Vichada              3197
# 1121   99773        Cumaribo      Vichada             19585
# 1122  999999     Consulados   Consulados             812071
#
#       Participación/Total votación   Abstención        Ganador  Votos Válidos  \
# 0                            979252      608898     Ivan Duque         965392
# 1                              7397        7570     Ivan Duque           7293
# ...

# %% [markdown]
# ## <center> $\color{blue}{\text{Data analysis}}$ </center>

# %% [markdown]
# Para entender los datos obtenidos primero debemos entender la definción de las variables presentadas en los datos, así como su jerarquia y correlaciones para un mejor entendimientos de estos y sus implicaciones.

# %% [markdown]
# * **Code:**
#
# La Codificación de la División Político Administrativa de Colombia es una nomenclatura estandarizada, diseñada por el DANE para la identificación de entidades territoriales (departamentos, distritos y municipios),áreas no municipalizadas y centros poblados, mediante la asignación de un código numérico único.
#
# * **Municipio**
#
# Los municipios de Colombia corresponden al segundo nivel de división administrativa en Colombia, que mediante agrupación conforman los departamentos.Colombia posee 1103 municipios registrados en el DANE (conteo que incluye los 8 distritos especiales que se cuentan también como municipios), más las 18 áreas no municipalizadas y la isla de San Andrés, en total son 1122 entidades administrativas locales.En Colombia los recursos pasan de la nación al departamento y de este al municipio. Cabe resaltar que el Distrito Capital funciona al nivel de un Departamento.
#
# * **Departamento**
#
# La Constitución de 1991 establece a Colombia como una república unitaria y descentralizada que se divide administrativa y políticamente en 33 divisiones: 32 departamentos, los cuales son gobernados desde sus respectivas ciudades capitales, y un distrito capital, Bogotá. Los departamentos forman áreas culturales y económicas dentro de las regiones geográficas. En Colombia los recursos pasan de la nación al departamento y de este al municipio; a excepción de Bogotá, que como distrito capital, recibe directamente de la nación (a través de ley de regalías).
#
# * **Censo Poblacional**
#
# El censo de población y vivienda realizado, consiste en contar y caracterizar las personas residentes en Colombia, así como las viviendas y los hogares del territorio nacional. A través del censo, el país obtiene datos de primera mano sobre el número de habitantes, su distribución en el territorio y sus condiciones de vida.
#
# Así, el censo no es solo una “fotografía” del país en un momento determinado, sino que permite generar información estadística que sirve para que diferentes organismos públicos y privados del país planeen y tomen decisiones de política pública, de desarrollo económico, bienestar social, empleo, vivienda, salud, migración, entre otros.
#
# * **Censo Electoral**
#
# La Ley 1475 de 2011, definió en su artículo 47 el censo electoral como “ el registro general de las cédulas de ciudadanía correspondientes a los ciudadanos colombianos, residentes en el país y en el exterior, habilitados por la Constitución y la ley para ejercer el derecho de sufragio y, por consiguiente, para participar en las elecciones y para concurrir a los mecanismos de participación ciudadana.
# El censo electoral determina el número de electores que se requiere para la validez de los actos y votaciones. Es también el instrumento técnico, elaborado por la Registraduría Nacional del Estado Civil, que le permite a la Organización Electoral planear, organizar, ejecutar y controlar los certámenes electorales y los mecanismos de participación ciudadana”.
#
# * **Participación Ciudadana**
#
# A partir de la promulgación de la Constitución Política de 1991, Colombia se convirtió en un Estado Social de Derecho, fundada sobre la democracia participativa, en este sentido, la ciudadanía tiene el derecho y el deber de participar directamente en la concertación, consulta, control y vigilancia de las decisiones que los afecten y, en general, en la vida económica, política, administrativa y cultural del pueblo. Así mismo, los servidores públicos son llamados a promover y apoyar el derecho de la participación de los ciudadanos.
#
# * **Abstención**
#
# Abstención, en ciencia política, es el acto por el cual un potencial votante en unas elecciones decide no ejercer su derecho al voto, ya sea en unas elecciones generales o si, en un procedimiento parlamentario, el representante está presente en la votación pero no vota. En ambos casos, el sujeto se atiene al resultado del voto de los electores que sí votaron, al igual que ocurre con el voto en blanco.
#
# Aunque la abstención no suele considerarse una de las opciones ante la toma colectiva de una decisión, una alta abstención se considera generalmente como beligerante o indiferente entre el cuerpo de votantes. Si la abstención se generaliza se pierde el bien público de la democracia
#
# * **Votos Validos**
#
# Son los votos depositados por cada uno de los candidatos inscritos más los votos en blanco. La suma de todos los votos depositados por los candidatos y votos en blanco arroja el total de votos válidos. No se incluyen dentro de los votos válidos los votos nulos ni las tarjetas no marcadas.
#
# * **Votos en blanco**
#
# De acuerdo con la sentencia C-490 de 2011 de la Corte Constitucional, que declaró la exequibilidad de la Ley 1475 (Reforma Política), el voto en blanco es “una expresión política de disentimiento, abstención o inconformidad, con efectos políticos” y agrega que “el voto en blanco constituye una valiosa expresión del disenso a través del cual se promueve la protección de la libertad del elector. Como consecuencia de este reconocimiento la Constitución le adscribe una incidencia decisiva en procesos electorales orientados a proveer cargos unipersonales y de corporaciones públicas de elección popular”.
#
# * **Votos nulos**
#
# Cuando la marcación efectuada por el elector no permite determinar de manera clara la intención del sufragante, es decir que no es posible identificar a favor de qué candidato votó.
#
# * **Tarjetones no marcados**
#
# La tarjeta no marcada es aquella en la cual a pesar de que el ciudadano la recibe, no la marca y la deposita en la urna sin haber seleccionado alguna opción. Por el contrario, la tarjeta no utilizada es aquella que al terminar la jornada queda en poder de los jurados y no fue entregada a los sufragantes. La tarjeta no marcada se contabiliza mientras que la no utilizada se destruye.

# %% [markdown]
# <img src="Jerarquia.png">

# %% [markdown]
# ##  $\color{blue}{\text{Participación ciudadana}}$ </center>

# %% [markdown]
# En orden de jerarquia el primer aspecto a analizar es la demografía electoral presentada entorno a la participación ciudadana,analizar el crecimiento o decrecimiento de esta implica factores tanto sociales como inherentes.
#
# Un primer factor extrinseco se derivada del crecimiento poblacional natural.En particular podemos verlo reflejado en nuestro intervalo temporal en análisis.

# %% [markdown]
# <img src="aumentopoblacion.png">

# %% [markdown]
# En específico,según la Registraduría Nacional del Estado Civil,las cifras evidencian que aunque el censo electoral creció de 1958 a 2010, en un promedio de 1.893.699 ciudadanos por cada elección presidencial,es decir en aproximadamente un 7.69% por periodo presidencial y en un 99.97% en los últimos 52 años, la participación política siempre ha fluctuado en el 56.52%.De los datos a continuación en el historico detallado se presenta un crecimiento congruente al población relativamente lineal en varias de las variables a analizar.

# %%
import pandas as pd
import openpyxl
wb = openpyxl.load_workbook('sufragiohistorico.xlsx')
ws = wb['Hoja1']
md = pd.DataFrame(ws.values)
md.columns = md.iloc[0]
md = md.drop(0)
md.head(27)
# Out:
# 0           Año     Censo Votos válidos Votos en   Votos Tarjetas no  \
# 1          None      None          None   blanco   nulos    marcadas
# 2          1958   5365191          None     8303    2165        None
# 3          1962   5404765          None     5822  683436        None
# 4          1966   6611352          None     9824    5529        None
# 5          1970   7683785          None    36892    5426        None
# 6          1974   8925330          None     6722    5869        None
# 7          1978  12580851          None     9923    7871        None
# 8          1982  13734093       6815660     8996    9594        None
# 9          1986  15611274          None    42205    8119        None
# 10         1990  14237110       6002274    77727   45302        None
# 11         1994  17146597       5791332    65116   29999        None
# 12  (1ª vuelta)      None          None     None    None        None
# 13         1994  17146597       7382653    72536   45089       43446
# ...

# %% [markdown]
# Ahora bien,todas estas cifras aunque presentan un cercanía cada una de ellas fueron producidas en contextos diferentes tanto en las formas de sufragio como en las politicas internas,los factores sociales que directa o indirectamente anclan el voto popular como por ejemplo problemas sociales,varios sonados fuertemente en las ultimas decadas,de allí la necesidad de relacionar las cifras con el contexto temporal en el que se encuentran,nuestro periodo a analizar naturalmente es el inmediatamente mas cercano en donde se evidencia el siguiente incremento de la participación y decrecimiento del abstencionismo.

# %% [markdown]
# <img src="aumentosufragio.png">

# %% [markdown]
# Veamos especificamente los comportamientos de cada uno de estos dos periodos en sus respectivas dos contiendas y en los distintos departamentos del pais

# %% [markdown]
# $2014$

# %% [markdown]
# <img src="20141.png">

# %% [markdown]
# <img src="20142.png">

# %% [markdown]
# $2018$

# %% [markdown]
# <img src="20181.png">

# %% [markdown]
# <img src="20182.png">

# %% [markdown]
# En los anteriores gráficos de barras se refleja la consistencia entre vueltas electorales por periodo y al igual se evidencia la concentración de poder de voto en algunos de los departamentos del pais.Para 2018 naturalmente se conserva la uniformidad en el baloteje sin embargo se refleja un importante alza tanto en el censo como en la participación política

# %% [markdown]
# Especificamente la distribución mantiene una tradicional consistencia la cual se reparte en los territorios de la siguiente forma

# %% [markdown]
# <img src="concentracionp.png">

# %% [markdown]
# Relacionando los fenomenos de concentración de poder y alza de participación podemos evidenciar la importancia de los centros más poblados objetivos siempre de candidatos y partidos.

# %% [markdown]
# <img src="pordepartamento.png">

# %% [markdown]
# ##  $\color{blue}{\text{Transiciones y transferencias electorales asociadas a Partidos Políticos}}$ </center>

# %% [markdown]
# $\color{blue}{\text{2014}}$

# %% [markdown]
# $Primera\;Vuelta$

# %%
votos=['Votos Oscar Iván Zuluaga',
 'Votos Juan Manuel Santos',
 'Votos Martha Lucía Ramírez','Votos Clara López Obregón','Votos Enrique Peñalosa']
Datos_10_2014[votos].sum()
# Out:
# Votos Oscar Iván Zuluaga      3769005
# Votos Juan Manuel Santos      3310794
# Votos Martha Lucía Ramírez    1997980
# Votos Clara López Obregón     1958518
# Votos Enrique Peñalosa        1064758
# dtype: int64

# %% [markdown]
# $Segunda\;Vuelta$

# %%
votos=['Juan Manuel Juan Manuel Santos',
 'Oscar Iván Oscar Iván Zuluaga']
Datos_20_2014[votos].sum()
# Out:
# Juan Manuel Juan Manuel Santos    7773117
# Oscar Iván Oscar Iván Zuluaga     6840973
# dtype: int64

# %% [markdown]
# |![alt](mapaelectoral20141.png), | ![alt](mapaelectoral20142.png) |
# |-|-|
# |![alt](labelmapa14.png), |

# %% [markdown]
# $\color{blue}{\text{2018}}$

# %% [markdown]
# $Primera\;Vuelta$

# %%
votos=['Iván Duque','Gustavo Petro','Sergio Fajardo','Germán Vargas Lleras','Humberto De La Calle','Jorge Antonio Trujillo ','Viviane Morales']
Datos_10_2018[votos].sum()
# Out:
# Iván Duque                 7617114.0
# Gustavo Petro              4854831.0
# Sergio Fajardo             4602916.0
# Germán Vargas Lleras       1412392.0
# Humberto De La Calle        396151.0
# Jorge Antonio Trujillo       65767.0
# Viviane Morales              36138.0
# dtype: float64

# %%
votos=['Iván Duque','Gustavo Petro']
Datos_20_2018[votos].sum()
# Out:
# Iván Duque       10398689
# Gustavo Petro     8039504
# dtype: int64

# %% [markdown]
# |![alt](mapaelectoral20181.png), | ![alt](mapaelectoral20182.png) |
# |-|-|
# |![alt](labelmapa18.png), |

# %% [markdown]
# TEXTO DOMINANCIA BILATERAL

# %% [markdown]
# ## $\color{darkblue}{\text{Centro Democrático}}$

# %% [markdown]
# $2014-1$

# %%
Depto=Datos_10_2014.groupby(['Depto'])['Votos Oscar Iván Zuluaga'].sum()
Depto.sort_values(ascending=False).head()
# Out:
# Depto
# Antioquia          665160
# Bogotá, D.C.       542459
# Cundinamarca       255598
# Valle del Cauca    216620
# Santander          186420
# Name: Votos Oscar Iván Zuluaga, dtype: int64

# %% [markdown]
# $2018-1$

# %%
Depto=Datos_10_2018.groupby(['Depto'])['Iván Duque'].sum()
Depto.sort_values(ascending=False).head()
# Out:
# Depto
# Antioquia          1375965.0
# Bogotá D.C.         989744.0
# Valle del Cauca     527622.0
# Cundinamarca        479936.0
# Santander           442219.0
# Name: Iván Duque, dtype: float64

# %% [markdown]
# ## $\color{orange}{\text{Antioquia}}$

# %% [markdown]
# 2014

# %%
votos=['Votos válidos','Votos Oscar Iván Zuluaga',
 'Votos Juan Manuel Santos',
 'Votos Martha Lucía Ramírez','Votos Clara López Obregón','Votos Enrique Peñalosa']
Antioquia=Datos_10_2014[Datos_10_2014['Depto']=='Antioquia']
ANT=Antioquia[votos].sum()
df=pd.DataFrame(ANT)
porc=df.assign(Porcentaje=ANT/df.iloc[0,0]*100)
porc
# Out:
#                                   0  Porcentaje
# Votos válidos               1766390  100.000000
# Votos Oscar Iván Zuluaga     665160   37.656463
# Votos Juan Manuel Santos     286742   16.233221
# Votos Martha Lucía Ramírez   334312   18.926285
# Votos Clara López Obregón    248628   14.075487
# Votos Enrique Peñalosa        98144    5.556191

# %%
votos=['Votos Válidos','Oscar Iván Oscar Iván Zuluaga','Juan Manuel Juan Manuel Santos']
Antioquia=Datos_20_2014[Datos_20_2014['Departamento']=='Antioquia']
ANT=Antioquia[votos].sum()
df=pd.DataFrame(ANT)
porc=df.assign(Porcentaje=ANT/df.iloc[0,0]*100)
porc
# Out:
#                                       0  Porcentaje
# Votos Válidos                   1967570  100.000000
# Oscar Iván Oscar Iván Zuluaga   1137735   57.824372
# Juan Manuel Juan Manuel Santos   704164   35.788511

# %% [markdown]
# 2018

# %%
votos=['Votos Válidos','Iván Duque','Gustavo Petro','Sergio Fajardo','Germán Vargas Lleras','Humberto De La Calle','Jorge Antonio Trujillo ','Viviane Morales']
Antioquia=Datos_10_2018[Datos_10_2018['Depto']=='Antioquia']
ANT=Antioquia[votos].sum()
df=pd.DataFrame(ANT)
porc=df.assign(Porcentaje=ANT/df.iloc[0,0]*100)
porc
# Out:
#                                  0  Porcentaje
# Votos Válidos            2575391.0  100.000000
# Iván Duque               1375965.0   53.427421
# Gustavo Petro             237206.0    9.210485
# Sergio Fajardo            732993.0   28.461426
# Germán Vargas Lleras       99182.0    3.851143
# Humberto De La Calle       59136.0    2.296195
# Jorge Antonio Trujillo      6985.0    0.271221
# Viviane Morales             4398.0    0.170770

# %%
votos=['Votos Válidos','Iván Duque','Gustavo Petro']
Antioquia=Datos_20_2018[Datos_20_2018['Depto']=='Antioquia']
ANT=Antioquia[votos].sum()
df=pd.DataFrame(ANT)
porc=df.assign(Porcentaje=ANT/df.iloc[0,0]*100)
porc
# Out:
#                      0  Porcentaje
# Votos Válidos  2547294  100.000000
# Iván Duque     1850996   72.665189
# Gustavo Petro   556685   21.853975

# %% [markdown]
# <img src="Centrodemocratico.png">

# %% [markdown]
# ## $\color{orange}{\text{Cundinamarca}}$

# %% [markdown]
# 2014

# %%
votos=['Votos válidos','Votos Oscar Iván Zuluaga',
 'Votos Juan Manuel Santos',
 'Votos Martha Lucía Ramírez','Votos Clara López Obregón','Votos Enrique Peñalosa']
Cundinamarca=Datos_10_2014[Datos_10_2014['Depto']=='Cundinamarca']
CUN=Cundinamarca[votos].sum()
df=pd.DataFrame(CUN)
porc=df.assign(Porcentaje=CUN/df.iloc[0,0]*100)
porc
# Out:
#                                  0  Porcentaje
# Votos válidos               808109  100.000000
# Votos Oscar Iván Zuluaga    255598   31.629149
# Votos Juan Manuel Santos    144346   17.862194
# Votos Martha Lucía Ramírez  186690   23.102082
# Votos Clara López Obregón   116562   14.424044
# Votos Enrique Peñalosa       56156    6.949063

# %%
votos=['Votos Válidos','Oscar Iván Oscar Iván Zuluaga','Juan Manuel Juan Manuel Santos']
Cundinamarca=Datos_20_2014[Datos_20_2014['Departamento']=='Antioquia']
CUN=Cundinamarca[votos].sum()
df=pd.DataFrame(CUN)
porc=df.assign(Porcentaje=CUN/df.iloc[0,0]*100)
porc
# Out:
#                                       0  Porcentaje
# Votos Válidos                   1967570  100.000000
# Oscar Iván Oscar Iván Zuluaga   1137735   57.824372
# Juan Manuel Juan Manuel Santos   704164   35.788511

# %% [markdown]
# 2018

# %%
votos=['Votos Válidos','Iván Duque','Gustavo Petro','Sergio Fajardo','Germán Vargas Lleras','Humberto De La Calle','Jorge Antonio Trujillo ','Viviane Morales']
Cundinamarca=Datos_10_2018[Datos_10_2018['Depto']=='Cundinamarca']
CUN=Cundinamarca[votos].sum()
df=pd.DataFrame(CUN)
porc=df.assign(Porcentaje=CUN/df.iloc[0,0]*100)
porc
# Out:
#                                  0  Porcentaje
# Votos Válidos            1185853.0  100.000000
# Iván Duque                479936.0   40.471795
# Gustavo Petro             236175.0   19.916044
# Sergio Fajardo            329857.0   27.816011
# Germán Vargas Lleras       85943.0    7.247357
# Humberto De La Calle       20545.0    1.732508
# Jorge Antonio Trujillo      4185.0    0.352911
# Viviane Morales             2611.0    0.220179

# %%
votos=['Votos Válidos','Iván Duque','Gustavo Petro']
Cundinamarca=Datos_20_2018[Datos_20_2018['Depto']=='Cundinamarca']
CUN=Cundinamarca[votos].sum()
df=pd.DataFrame(CUN)
porc=df.assign(Porcentaje=CUN/df.iloc[0,0]*100)
porc
# Out:
#                      0  Porcentaje
# Votos Válidos  1166553  100.000000
# Iván Duque      661521   56.707325
# Gustavo Petro   450382   38.607933

# %% [markdown]
# ## $\color{purple}{\text{Colombia Humana}}$

# %%
Depto=Datos_10_2018.groupby(['Depto'])['Gustavo Petro'].sum()
Depto.sort_values(ascending=False).head()
# Out:
# Depto
# Bogotá D.C.        1099955
# Valle del Cauca     485867
# Atlántico           331979
# Córdoba             250437
# Bolívar             242471
# Name: Gustavo Petro, dtype: int64

# %% [markdown]
# ## $\color{orange}{\text{Bogotá}}$

# %% [markdown]
# 2018-I

# %%
votos=['Votos Válidos','Sergio Fajardo','Gustavo Petro','Iván Duque','Germán Vargas Lleras','Humberto De La Calle','Jorge Antonio Trujillo ','Viviane Morales']
Bogota=Datos_10_2018[Datos_10_2018['Depto']=='Bogotá D.C.']
BOG=Bogota[votos].sum()
df=pd.DataFrame(BOG)
porc=df.assign(Porcentaje=BOG/df.iloc[0,0]*100)
porc
# Out:
#                                  0  Porcentaje
# Votos Válidos            3676217.0  100.000000
# Sergio Fajardo           1244477.0   33.852109
# Gustavo Petro            1099955.0   29.920840
# Iván Duque                989744.0   26.922894
# Germán Vargas Lleras      172684.0    4.697329
# Humberto De La Calle       93401.0    2.540682
# Jorge Antonio Trujillo     10696.0    0.290951
# Viviane Morales             5492.0    0.149393

# %% [markdown]
# 2018-II

# %%
votos=['Votos Válidos','Gustavo Petro','Iván Duque']
Bogota=Datos_20_2018[Datos_20_2018['Depto']=='Bogotá D.C.']
BOG=Bogota[votos].sum()
df=pd.DataFrame(BOG)
porc=df.assign(Porcentaje=BOG/df.iloc[0,0]*100)
porc
# Out:
#                      0  Porcentaje
# Votos Válidos  3538391  100.000000
# Gustavo Petro  1889050   53.387260
# Iván Duque     1449092   40.953416

# %% [markdown]
# <img src="ColombiaHumana.png">

# %% [markdown]
# ## $\color{orange}{\text{Valle del Cauca}}$

# %% [markdown]
# 2018-I

# %%
votos=['Votos Válidos','Iván Duque','Sergio Fajardo','Gustavo Petro','Germán Vargas Lleras','Humberto De La Calle','Jorge Antonio Trujillo ','Viviane Morales']
Valle=Datos_10_2018[Datos_10_2018['Depto']=='Valle del Cauca']
VAL=Valle[votos].sum()
df=pd.DataFrame(VAL)
porc=df.assign(Porcentaje=VAL/df.iloc[0,0]*100)
porc
# Out:
#                                  0  Porcentaje
# Votos Válidos            1747769.0  100.000000
# Iván Duque                527622.0   30.188314
# Sergio Fajardo            502367.0   28.743329
# Gustavo Petro             485867.0   27.799269
# Germán Vargas Lleras      137373.0    7.859906
# Humberto De La Calle       40858.0    2.337723
# Jorge Antonio Trujillo      6852.0    0.392043
# Viviane Morales             2971.0    0.169988

# %% [markdown]
# 2018-II

# %%
votos=['Votos Válidos','Gustavo Petro','Iván Duque']
Valle=Datos_20_2018[Datos_20_2018['Depto']=='Valle del Cauca']
VAL=Valle[votos].sum()
df=pd.DataFrame(VAL)
porc=df.assign(Porcentaje=VAL/df.iloc[0,0]*100)
porc
# Out:
#                      0  Porcentaje
# Votos Válidos  1713969  100.000000
# Gustavo Petro   888023   51.810914
# Iván Duque      747733   43.625818

# %% [markdown]
# <img src="valledelcauca.png">

# %% [markdown]
# ## <center> $\color{teal}{\text{Especificación del modelo de ML}}$ </center>

# %% [markdown]
# $\color{teal}{\text{Motivación del proyecto de ML}}$

# %% [markdown]
# Como lo vimos en los datos del proyecto ‘Análisis del panorama político para las elecciones presidenciales de 2022 ’estos no solo ofrecen la cantidad de votos obtenidos por un candidato, sino que además generan todo un entorno y caracterización demográfica respecto al entorno político-social y preferencias ciudadanas, el cual resulta de gran importancia poder observar y comprender.
# Así mismo, dentro del desarrollo del proyecto se planteó el contraste cuantitativo como medida de desempeño y éxito de las cifras obtenidas de las distintas variables a analizar frente a los sondeos actuales realizados por las firmas encuestadoras donde si bien se posee un alto nivel de congruencia respecto a las proyecciones y los resultados en las urnas también se presenta un margen de error considerable pues aunque las firmas encuestadoras intentan tomar un grupo muestral característico este aún puede verse aún reducido en comparación con el tamaño real de la población .
# Hoy en día el Machine Learning es fuertemente aplicado en el entorno social, desde la publicidad mostrada a cada usuario hasta el mismo algoritmo que los clasifica entre sí y por lo tanto el ámbito político no se queda atrás pues hoy en día las redes sociales son el primer lugar para divulgar las posturas respecto a algún tema y en particular políticas.
# La aplicación del presente proyecto al Machine Learning que se pretende abordar es como las redes sociales pueden establecer métricas más exactas de las posturas políticas de los individuos tomando no solo un grupo mas cuantioso sino además con mayor activismo y presencia en divulgación e influencia clave en la sociedad de hoy en día.

# %% [markdown]
# <img src="MLUSA.jpg">

# %% [markdown]
# $\color{teal}{\text{Definición del problema}}$

# %% [markdown]
# $\color{teal}{\text{Salida}}$

# %% [markdown]
# La buena ejecución del problema de ML debería proporcionar si una persona es afín o no a un candidato o hay una posible intención de voto de los distintos ciudadanos en los diferentes territorios y departamentos a un candidato proporcionando una polaridad positiva negativa o neutra, esto de forma análoga a lo obtenido en la analítica de datos, pero esta vez mediante el análisis de las opiniones y comentarios publicados en tiempo real en las distintas redes sociales de gran flujo de texto y fácil accesibilidad como por ejemplo Twitter.

# %% [markdown]
# $\color{teal}{\text{Entrada}}$

# %% [markdown]
# Para la recopilación de la entrada de datos a trabajar en el proceso de analítica de datos en este caso puntual los tweets, se deben tener en cuenta distintos factores de selección y clasificación, esto con el fin de obtener una mayor calidad en la información en materia de magnitud y contenido, algunos de los más relevantes para tener en cuenta podrían ser:

# %% [markdown]
# -	**Selección reciente:**
#
#     Si bien una parte de la población es fiel a sus posturas unas las cuestiones que mas se analiza en una contienda electoral es el ‘sentimiento popular’ y la variación de este por lo cual un escaneo a la red de a lo mas 3-4 meses previos a las elecciones contienen información más sólida.

# %% [markdown]
# - **Mayor cantidad de trafico social**
#
#     Existen horas del día donde el trafico de redes sociales es mucho mayor comparado con otras franjas horarias y esto en política fuertemente conectado cuando los medios de comunican masiva se pronuncian respecto a algún tema que de cierta forma directa o indirecta atañe a algún candidato o partido político y lo anterior cruzado cuando las personas tienen más presencia en sus redes como lo son las horas sociales y no laborales.

# %% [markdown]
# - **Anclaje a eventos políticos**
#
#     Este se deriva del factor inmediatamente anterior y es que cuando algún personaje político se pronuncia o actúa de determinada forma respecto a algún tema esto genera una ola de comentarios y reacciones de con alto flujo y expansión en la red.

# %% [markdown]
# - **Geolocalización**
#
#     Resulta mas que necesario seccionar los datos por territorios pues de esto depende el dominio de un candidato en un territorio pues esto se logra en la obtención de un sufragante y la expansión en sus círculos sociales más próximos como los son familiares y amigos ,aunque si bien cada voto cuenta por el análisis de datos visto en el proyecto la concentración del poder de voto se encuentra en las principales capitales; De igual forma el histórico de afinidad de partidos políticos a  departamentos

# %% [markdown]
# Una vez recopilados los tweets producidos en determinado tiempo debe ser posible filtrarlos para solo seleccionar los que son afines a nuestro estudio político y esto se logra mediante el previo entrenamiento del modelo el cual claramente debe ser supervisado pues la conexión léxica con las distintas expresiones y la biblioteca de posibles nexos para deducir un sentimiento de intención de voto es bastante amplia.

# %% [markdown]
# $\color{teal}{\text{DataSet}}$

# %% [markdown]
# $\color{black}{\text{Número de registros de entrenamiento}}$
#
# Establecer un numero de entrenamientos es algo nada rudimentario sin embargo es claro que este debe ser un considerable diccionario de palabras anclado a los temas y sujetos de las próximas contiendas, algunos de estos a considerar deben ser:

# %% [markdown]
# $\color{black}{\text{Para la obtención:}}$

# %% [markdown]
# <img src="MLDATASET1.png">

# %% [markdown]
# $\color{black}{\text{Para la filtración:}}$

# %% [markdown]
# <img src="MLDATASET2.png">

# %% [markdown]
# $\color{teal}{\text{Datos no balanceados y sesgos}}$

# %% [markdown]
# Un posible sesgo sistemático puede provenir de la cantidad de interpretaciones que pueden tener hoy en día las expresiones incluso por más cortas que estas sean, en el trabajo de toma y filtración se deben tener varias capas de procesamiento que consideren o descarten situaciones como:

# %% [markdown]
# •	Monosílabos sin conexión, cadenas de caracteres ilegibles
#
# •	Tweets que no presentan conexión con algún tema político
#
# •	Imágenes
#
# •	Links, sitios de redirección, tweets automatizados de página clasificadas como Spam
#
# •	Expresiones coloquiales o determinadas formas de referirse a una cosa, tema o sujeto de una forma no tan literal
#
# •	Expresiones en tono irónico o subjetivo donde no se refleje con inmediata claridad una verdadera favorabilidad o desfavorabilidad

# %% [markdown]
# Si bien estos filtros pueden descartar el posible ruido de la cantidad de datos también están las formas directas de anclar los tweets de importancia directa como los son nombrar de forma explícita al candidato, así como las tendencias y hashtags
#
# Otros posibles sesgos mas ligados al sujeto pueden ser:
#
# •	Cuentas de menores de edad
#
# •	Cuentas ligadas a empresas u organizaciones caracterizadas por la difusión de contenido y que no pertenecen a ningún sujeto en particular

# %% [markdown]
# $\color{teal}{\text{Frecuencia}}$

# %% [markdown]
# Como lo dicho anteriormente es necesario fijar un periodo cercano a las elecciones, dentro de este periodo se podría considerar un escaneo semanal en una franja horaria pues esto nada más genera una gran cantidad de datos, la periodicidad  ayudaría aportando no solo a variabilidad de población y cantidad de sujetos sino además tomando en cuenta los eventos o situaciones claves que van ocurriendo en momentos claves como los son los cierres de campañas que derivan eventos masivos y posturas de diferentes colectivos y gremios.

# %% [markdown]
# $\color{teal}{\text{Predicción}}$

# %% [markdown]
# Tras una selección y filtración de calidad en los datos recopilados en la red el siguiente paso clave es la clasificación, el entendimiento de la información permitirá categorizar complementariamente en positivo o negativo, favorable o desfavorables, de donde categorizando cada opinión y tomando un buen tamaño muestral se podría recopilar y dar un porcentaje de que dado un total de población que fracción de esta votaría por determinado candidato. Como veremos más adelante en la literatura relacionada con el problema se presenta fuertemente la conexión entre el clasificador Naive-Bayes junto con la estimación y valoración que dan la herramienta crucial a los algoritmos para finalmente arrojar un dato cuantitativo que pueda ser traducido a los distintos actores interesados en el problema

# %%
import twint

# %%
URL='Prueba1.xlsx'
HOJA='Prueba'
Tweets=pd.read_excel(URL,sheet_name=HOJA)

# %%
Tweets
# Out:
#                       id      conversation_id  \
# 0    1433749039011529984  1433575210037509888
# 1    1433745090514660096  1433543355934320128
# 2    1433678054715529984  1432796927901449984
# 3    1433659794867589888  1433590174747930112
# 4    1433629505483120128  1432312227386850048
# ..                   ...                  ...
# 224  1432997837688780032  1432717887848979968
# 225  1432952184832920064  1432847808411930112
# 226  1432951051242569984  1432881943834670080
# 227  1432941894082899968  1432707120982599936
# 228  1432935341011389952  1432883830453639936
#
#                                             created_at       date      time  \
# 0    2021-09-03 06:09:43 Hora est. PacÃ­fico, Sudam... 2021-09-03  06:09:43
# 1    2021-09-03 05:54:01 Hora est. PacÃ­fico, Sudam... 2021-09-03  05:54:01
# 2    2021-09-03 01:27:39 Hora est. PacÃ­fico, Sudam... 2021-09-03  01:27:39
# 3    2021-09-03 00:15:05 Hora est. PacÃ­fico, Sudam... 2021-09-03  00:15:05
# ...

# %%
df=pd.DataFrame(Tweets['tweet'])

# %%
df
# Out:
#                                                  tweet
# 0    @sergio_fajardo @agaviriau @CoaliEsperanza Ni ...
# 1    @agaviriau Gran esperanza para colombia! OjalÃ...
# 2    @agaviriau Usted hace parte del continuismo,no...
# 3    @alinpinpri @JuanAngelTin @NeiderCamargo5 @Dav...
# 4    @CharlyDoval @franja_uno @AndresCamiloHR @ciel...
# ..                                                 ...
# 224  @juankyospina @chococongas @RevistaSemana Y @p...
# 225  @ArgiroCasta58 Me choca ver a la gente posando...
# 226  @marcelamvz Yo te digo. Yo voto en 1era vuelta...
# 227  @santiagoecheve @todoscolombia @petrogustavo @...
# 228  @petrogustavo Soy liberal pero mi Voto es por ...
#
# [229 rows x 1 columns]

# %%
import re
def clean_tweets(text):
  text = re.sub("RT @[\w]*:","",text)
  #text = re.sub("@[\w]*","",text)
  text = re.sub("https?://[A-Za-z0-9./]*","",text)
  text = re.sub("\n","",text)
  return text
df['tweet'] = df['tweet'].apply(lambda x: clean_tweets(x))
df.head(20)
# Out:
#                                                 tweet
# 0   @sergio_fajardo @agaviriau @CoaliEsperanza Ni ...
# 1   @agaviriau Gran esperanza para colombia! OjalÃ...
# 2   @agaviriau Usted hace parte del continuismo,no...
# 3   @alinpinpri @JuanAngelTin @NeiderCamargo5 @Dav...
# 4   @CharlyDoval @franja_uno @AndresCamiloHR @ciel...
# 5   @DiegoTrujilloD @agaviriau Claaaaaro, ya sabem...
# 6   @MaoS_777 @sergio_fajardo @agaviriau @CoaliEsp...
# 7   @sergio_fajardo @agaviriau @CoaliEsperanza Si ...
# 8   @DiegoTrujilloD @agaviriau Este es otro que vo...
# 9   @agaviriau Solo puedo decirle algo, de ganar, ...
# 10  @plagiosos @beticovergara @agaviriau Entonces ...
# 11  @agaviriau Excelente ser humano , mi voto por ...
# 12       @DanielSamperO 10. Mi voto es por @agaviriau
# 13  @DiegoTrujilloD @agaviriau Gaviria es la nueva...
# 14  @DiegoTrujilloD @agaviriau Petardo, otra vez v...
# 15  @DiegoTrujilloD @agaviriau Alejandro me habla ...
# ...

# %%
from textblob import TextBlob

# %%
TextBlob ('Odio a Petro').translate(from_lang='es',to='en').sentiment
# Out:
# Sentiment(polarity=-0.8, subjectivity=0.9)

# %%
TextBlob ('Mejor opcion petro').translate(from_lang='es',to='en').sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
TextBlob ('Peor opcion petro').translate(from_lang='es',to='en').sentiment
# Out:
# Sentiment(polarity=-1.0, subjectivity=1.0)

# %%
import time
def get_polarity(text):
  analysis = TextBlob(text)
  if text != '':
    if analysis.detect_language() == 'es':
      result = analysis.translate(from_lang = 'es', to = 'en').sentiment.polarity
      time.sleep(5)
      return result

# %%
A = df[1:30]
#df['polarity'] = df['tweet'].apply(get_polarity)

# %%
A
# Out:
#                                                 tweet
# 1   @agaviriau Gran esperanza para colombia! OjalÃ...
# 2   @agaviriau Usted hace parte del continuismo,no...
# 3   @alinpinpri @JuanAngelTin @NeiderCamargo5 @Dav...
# 4   @CharlyDoval @franja_uno @AndresCamiloHR @ciel...
# 5   @DiegoTrujilloD @agaviriau Claaaaaro, ya sabem...
# 6   @MaoS_777 @sergio_fajardo @agaviriau @CoaliEsp...
# 7   @sergio_fajardo @agaviriau @CoaliEsperanza Si ...
# 8   @DiegoTrujilloD @agaviriau Este es otro que vo...
# 9   @agaviriau Solo puedo decirle algo, de ganar, ...
# 10  @plagiosos @beticovergara @agaviriau Entonces ...
# 11  @agaviriau Excelente ser humano , mi voto por ...
# 12       @DanielSamperO 10. Mi voto es por @agaviriau
# 13  @DiegoTrujilloD @agaviriau Gaviria es la nueva...
# 14  @DiegoTrujilloD @agaviriau Petardo, otra vez v...
# 15  @DiegoTrujilloD @agaviriau Alejandro me habla ...
# 16  @sergio_fajardo @CoaliEsperanza @agaviriau Es ...
# ...

# %%
A['tweet'].apply(get_polarity)
# Out:
# 1     1.000000
# 2     0.017857
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.295312
# 7    -0.002381
# 8     0.250000
# 9     0.400000
# 10    0.000000
# 11    0.500000
# 12    0.000000
# 13   -0.231818
# 14   -0.250000
# 15    0.216667
# 16    0.133333
# 17   -0.200000
# 18   -0.100000
# 19    0.000000
# 20    0.000000
# 21    0.066667
# 22    0.000000
# 23    0.100000
# 24    0.000000
# 25   -0.333333
# 26   -0.650000
# 27   -0.127500
# 28    0.250000
# 29    0.000000
# Name: tweet, dtype: float64
